# %%
# important import statements
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import os,sys

from PIL import Image
from torchvision.transforms import Resize, Compose, ToTensor, Normalize
import numpy as np
import skimage
import matplotlib.pyplot as plt

import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class SineLayer(nn.Module):
    # See paper sec. 3.2, final paragraph, and supplement Sec. 1.5 for discussion of omega_0.

    # If is_first=True, omega_0 is a frequency factor which simply multiplies the activations before the
    # nonlinearity. Different signals may require different omega_0 in the first layer - this is a
    # hyperparameter.

    # If is_first=False, then the weights will be divided by omega_0 so as to keep the magnitude of
    # activations constant, but boost gradients to the weight matrix (see supplement Sec. 1.5)

    def __init__(self, in_features, out_features, bias=True,
                 is_first=False, omega_0=30):
        super().__init__()
        self.omega_0 = omega_0
        self.is_first = is_first

        self.in_features = in_features
        self.linear = nn.Linear(in_features, out_features, bias=bias)

        self.init_weights()

    def init_weights(self):
        with torch.no_grad():
            if self.is_first:
                self.linear.weight.uniform_(-1 / self.in_features,
                                             1 / self.in_features)
            else:
                self.linear.weight.uniform_(-np.sqrt(6 / self.in_features) / self.omega_0,
                                             np.sqrt(6 / self.in_features) / self.omega_0)

    def forward(self, input):
        return torch.sin(self.omega_0 * self.linear(input))

    def forward_with_intermediate(self, input):
        # For visualization of activation distributions
        intermediate = self.omega_0 * self.linear(input)
        return torch.sin(intermediate), intermediate


class Siren(nn.Module):
    def __init__(self, in_features, hidden_features, hidden_layers, out_features, outermost_linear=False,
                 first_omega_0=30, hidden_omega_0=30.):
        super().__init__()

        self.net = []
        self.net.append(SineLayer(in_features, hidden_features,
                                  is_first=True, omega_0=first_omega_0))

        for i in range(hidden_layers):
            self.net.append(SineLayer(hidden_features, hidden_features,
                                      is_first=False, omega_0=hidden_omega_0))

        if outermost_linear:
            final_linear = nn.Linear(hidden_features, out_features)

            with torch.no_grad():
                final_linear.weight.uniform_(-np.sqrt(6 / hidden_features) / hidden_omega_0,
                                              np.sqrt(6 / hidden_features) / hidden_omega_0)

            self.net.append(final_linear)
        else:
            self.net.append(SineLayer(hidden_features, out_features,
                                      is_first=False, omega_0=hidden_omega_0))

        self.net = nn.Sequential(*self.net)

    def forward(self, coords):
        coords = coords.clone().detach().requires_grad_(True) # allows to take derivative w.r.t. input
        output = self.net(coords)
        return output, coords

    def forward_with_activations(self, coords, retain_grad=False):
        '''Returns not only model output, but also intermediate activations.
        Only used for visualizing activations later!'''
        activations = OrderedDict()

        activation_count = 0
        x = coords.clone().detach().requires_grad_(True)
        activations['input'] = x
        for i, layer in enumerate(self.net):
            if isinstance(layer, SineLayer):
                x, intermed = layer.forward_with_intermediate(x)

                if retain_grad:
                    x.retain_grad()
                    intermed.retain_grad()

                activations['_'.join((str(layer.__class__), "%d" % activation_count))] = intermed
                activation_count += 1
            else:
                x = layer(x)

                if retain_grad:
                    x.retain_grad()

            activations['_'.join((str(layer.__class__), "%d" % activation_count))] = x
            activation_count += 1

        return activations

# %% [markdown]
# And finally, differential operators that allow us to leverage autograd to compute gradients, the laplacian, etc.

# %%
def laplace(y, x):
    grad = gradient(y, x)
    return divergence(grad, x)

def divergence(y, x):
    div = 0.
    for i in range(y.shape[-1]):
        div += torch.autograd.grad(y[..., i], x, torch.ones_like(y[..., i]), create_graph=True,allow_unused=True)[0][..., i:i+1]
    return div


def gradient(y, x, grad_outputs=None):

    if grad_outputs is None:
        grad_outputs = torch.ones_like(y)
    grad = torch.autograd.grad(y, [x], grad_outputs=grad_outputs, create_graph=True,allow_unused=True)[0]
    return grad

# %%
# function to read and pre-process the MeerKAT fits file
def get_meerkat_image(sidelength):
  from astropy.io import fits
  import numpy as np
  filename = "/content/drive/MyDrive/Colab Notebooks/MeerKAT_Galactic_Centre_1284MHz-StokesI.fits"
  with fits.open(filename) as hdul:
      x_dim, y_dim = hdul[0].data.shape
      dim_max = min(x_dim, y_dim)
      assert sidelength%2 == 0
      x_min, y_min = int(6000-sidelength/2), int(5000-sidelength/2)
      x_max,y_max = int(6000+sidelength/2), int(5000+sidelength/2)
      if x_max > dim_max:
        dx = x_max-dim_max
        x_max = dim_max
        x_min = max(0,x_min-dx)
      if y_max > dim_max:
        dy = y_max-dim_max
        y_max = dim_max
        y_min = max(0,y_min-dy)
      print("Reading MeerKAT_Galactic_Centre_1284MHz-StokesI x:{0}-{1}, y:{2}-{3}".format(x_min,x_max,y_min,y_max))
      data = hdul[0].data[x_min:x_max,y_min:y_max].astype(np.float32)
  data = data-np.nanmin(data)
  data+=1e-5
  data=np.log(data)
  data = data-np.nanmin(data)
  data = data/np.nanmax(data)
  img =  Image.fromarray(data)
  del data
  transform = Compose([
      Resize(sidelength),
      ToTensor(),
      Normalize(torch.Tensor([0.5]), torch.Tensor([0.5]))
  ])
  img = transform(img)
  return img

# %%
# coordinate grid definition
def get_mgrid(sidelen, dim=2):
    '''Generates a flattened grid of (x,y,...) coordinates in a range of -1 to 1.
    sidelen: int
    dim: int'''
    tensors = tuple(dim * [torch.linspace(-1, 1, steps=sidelen)])
    mgrid = torch.stack(torch.meshgrid(*tensors), dim=-1)
    mgrid = mgrid.reshape(-1, dim)
    return mgrid

# imagefitting class which handles the network's view of the data
class ImageFitting(Dataset):
    def __init__(self, sidelength, pixels_per_iter = 256**2, weighted_selection = False):
        super().__init__()
        self.N_pixels_per_iter = pixels_per_iter
        self.sidelength = sidelength

        # load data and get pixels and coordinates
        img = get_meerkat_image(sidelength)
        self.pixels = img.permute(1, 2, 0).view(-1, 1)
        self.coords = get_mgrid(sidelength, 2)

        # remove NaNs so that network doesn't see them during training
        NaN_mask = ~torch.isnan(self.pixels.reshape(-1))
        N_Nans = torch.sum(~NaN_mask)
        if N_Nans > 0:
          print("Removing {0} pixels with NaN values from training, {1:.2f}% of all pixels".format(N_Nans,N_Nans/sidelength**2*100))
          if N_Nans == sidelength**2:
            print("All pixels are Nans... exiting.")
            sys.exit()
        self.pixels_noNan = self.pixels[NaN_mask]
        self.coords_noNan = self.coords[NaN_mask,:]
        self.N_noNan_pixels = self.pixels_noNan.shape[0]

        print("Network will see {0} pixels during training, {1:.2f}% of non-NaN pixels".format(pixels_per_iter,pixels_per_iter/self.N_noNan_pixels*100))

        # probability distribution for selecting pixels
        if weighted_selection:
          self.P = 1 + self.pixels_noNan.reshape(-1).numpy()
          self.P /= np.sum(self.P)
        else: self.P = None

    def __len__(self):
        return 1

    def get_coords(self):
        return self.coords

    # get a subset of the full image coordinates
    # useful for visualization during training
    # or for defining a new loss only using this subset
    def get_sparse_coords(self,sparsesidelength):
        assert self.sidelength%sparsesidelength==0
        return get_mgrid(sparsesidelength, 2)

    # get a subset of the full image pixels
    # useful for visualization during training
    def get_sparse_pixels(self,sparse_coords):
        assert self.pixels.shape[0]%sparse_coords.shape[0]==0
        f = int(np.sqrt(int(self.pixels.shape[0]/sparse_coords.shape[0])))
        pixels = self.pixels.reshape(self.sidelength,self.sidelength,1)
        sparse_pixels = pixels[::f,::f,:].reshape(-1,1)
        assert sparse_pixels.shape[0] == sparse_coords.shape[0]
        return sparse_pixels

    def get_pixels(self):
        return self.pixels

    def __getitem__(self, idx):
        if idx > 0: raise IndexError
        # choose random N_pixels_per_iter out of N_total_pixels
        idx = np.random.choice(self.N_noNan_pixels, self.N_pixels_per_iter,replace=False,p=self.P)
        pixels = self.pixels_noNan[idx,:]
        coords = self.coords_noNan[idx,:]
        return coords, pixels

# %%
# we extract a square cutout of sidelength x sidelength
# pixels_per_iter defines how many pixels the network will try to fit in each training iteration
# weighted_selection will use a probability distribution to choose the pixels in each training iteration
sidelength = 1024*2
milkyway = ImageFitting(sidelength,pixels_per_iter = 256**2,weighted_selection=True)
dataloader = DataLoader(milkyway, batch_size=1, pin_memory=True, num_workers=0)

img_siren = Siren(in_features=2, out_features=1, hidden_features=256,
                  hidden_layers=3, outermost_linear=True)
img_siren.cuda()
# Out:
# Reading MeerKAT_Galactic_Centre_1284MHz-StokesI x:4976-7024, y:3976-6024
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4381.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Network will see 65536 pixels during training, 1.56% of non-NaN pixels
# Siren(
#   (net): Sequential(
#     (0): SineLayer(
#       (linear): Linear(in_features=2, out_features=256, bias=True)
#     )
#     (1): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (2): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (3): SineLayer(
#       (linear): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (4): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %%
total_steps = 1000 # Since the whole image is our dataset, this just means 500 gradient descent steps.
steps_til_summary = 50

optim = torch.optim.Adam(lr=1e-4, params=img_siren.parameters())

sparse_sidelength = 256
sparse_coords = milkyway.get_sparse_coords(sparse_sidelength)
sparse_pixels = milkyway.get_sparse_pixels(sparse_coords)
sparse_coords = sparse_coords.cuda()

loss_history = []

for step in range(total_steps):
    coords, true_pixels = next(iter(dataloader))
    coords, true_pixels = coords.cuda().detach(), true_pixels.cuda().detach()

    model_output, __ = img_siren(coords)
    loss = ((model_output - true_pixels)**2).mean()
    loss_history.append(loss.item())

    if not step % steps_til_summary:
        with torch.no_grad():
          print("Step %d, Total loss %0.6f" % (step, loss))
          fig, axes = plt.subplots(1,2, figsize=(4,2))
          model_output,__ = img_siren(sparse_coords)
          axes[0].imshow( model_output.cpu().view(sparse_sidelength,sparse_sidelength).detach().numpy())
          axes[1].imshow(sparse_pixels.cpu().view(sparse_sidelength,sparse_sidelength).detach().numpy())
          plt.show()

    optim.zero_grad()
    loss.backward()
    optim.step()
# Out:
# Step 0, Total loss 0.045148
# Step 50, Total loss 0.001341
# Step 100, Total loss 0.001077
# Step 150, Total loss 0.000950
# Step 200, Total loss 0.000862
# Step 250, Total loss 0.000740
# Step 300, Total loss 0.000677
# Step 350, Total loss 0.000585
# Step 400, Total loss 0.000540
# Step 450, Total loss 0.000515
# Step 500, Total loss 0.000484
# Step 550, Total loss 0.000437
# Step 600, Total loss 0.000411
# Step 650, Total loss 0.000383
# Step 700, Total loss 0.000360
# Step 750, Total loss 0.000341
# Step 800, Total loss 0.000317
# Step 850, Total loss 0.000295
# Step 900, Total loss 0.000283
# Step 950, Total loss 0.000265

# %%
# Visualization after training
import matplotlib.colors as colors

all_coords    = milkyway.get_coords()
all_pixels    = milkyway.get_pixels()

# Initialize tensors to store the full reconstructed image, gradients, and Laplacian
full_model_output   = torch.empty_like(all_pixels)
full_grad_output    = torch.zeros(all_pixels.shape[0],  2, device=all_pixels.device)
full_laplace_output = torch.empty_like(all_pixels)

# Define a smaller batch size for gradient/laplacian visualization to prevent OOM
batch_size_pixels_viz = 2048 # Reduced batch size for visualization of gradients/laplacian
num_batches_viz = (milkyway.sidelength**2  + batch_size_pixels_viz - 1) // batch_size_pixels_viz

# Process the full image in batches for visualization
for i in range(num_batches_viz):
    start_idx_viz = i * batch_size_pixels_viz
    end_idx_viz = min((i + 1) * batch_size_pixels_viz, milkyway.sidelength**2)

    # Siren's forward method internally creates a tensor with requires_grad=True
    # We need to capture this internal tensor for calculating gradients and Laplacian.
    batch_input_coords = all_coords[ start_idx_viz:end_idx_viz,:].cuda().float().clone().detach().requires_grad_(True)
    model_output,model_coords = img_siren(batch_input_coords) # Get the internal coords from Siren

    # Calculate gradients and Laplacian
    img_grad = torch.autograd.grad(model_output, model_coords, grad_outputs=torch.ones_like(model_output), create_graph=True,allow_unused=True)[0]
    img_laplacian = laplace(model_output, model_coords)

    # Store results in the full tensors
    full_model_output[  start_idx_viz:end_idx_viz, :] = model_output.detach()
    full_grad_output[   start_idx_viz:end_idx_viz, :] = img_grad.detach()
    full_laplace_output[start_idx_viz:end_idx_viz, :] = img_laplacian.detach()

# Plot the results
fig, axes = plt.subplots(2,3, figsize=(9,6)) # Adjusted figsize for better viewing
axes=axes.flatten()

# Shared colour scale for original & reconstructed
vmin = all_pixels.min().item()
vmax = all_pixels.max().item()

# Original Image
c0 = axes[0].imshow(
    all_pixels.cpu().view(sidelength, sidelength).detach().numpy(),
    cmap='magma',
    vmin=vmin,
    vmax=vmax
)
axes[0].set_title("Original Image")
axes[0].axis('off') # Hide axes for cleaner image display


# Reconstructed Image
c1 = axes[1].imshow(
    full_model_output.cpu().view(sidelength, sidelength).detach().numpy(),
    cmap='magma',
    vmin=vmin,
    vmax=vmax
)
axes[1].set_title("Reconstructed Image")
axes[1].axis('off') # Hide axes for cleaner image display

# Gradient Magnitude
# Normalize gradient magnitude for better visualization, if needed
grad_magnitude = full_grad_output.norm(dim=-1).cpu().view(sidelength, sidelength).detach().numpy()
c2 = axes[2].imshow(grad_magnitude, cmap='magma') # Using a different colormap for gradients
axes[2].set_title("Gradient Magnitude")
axes[2].axis('off')

# Laplacian
# Normalize Laplacian for better visualization, if needed
laplacian_output = full_laplace_output.cpu().view(sidelength, sidelength).detach().numpy()
c3 = axes[3].imshow(laplacian_output, cmap='seismic',norm=colors.CenteredNorm(halfrange=100)) # Centered colormap for Laplacian
axes[3].set_title("Laplacian")
axes[3].axis('off')

# Residuals
residual = (all_pixels-full_model_output).cpu().view(sidelength, sidelength).detach().numpy()
c4 = axes[4].imshow(residual, cmap='seismic',norm=colors.CenteredNorm()) # Centered colormap for Laplacian
axes[4].set_title("Residual Error")
axes[4].axis('off')

axes[5].plot([s for s in range(total_steps)],loss_history)
axes[5].set_title("History")
axes[5].set_xlabel("Step")
axes[5].set_ylabel("MSE Loss")
asp = np.diff(axes[5].get_xlim())[0] / np.diff(axes[5].get_ylim())[0]
axes[5].set_aspect(asp)

plt.colorbar(c0, ax=axes[0],shrink=0.5)
plt.colorbar(c1, ax=axes[1],shrink=0.5)
plt.colorbar(c2, ax=axes[2],shrink=0.5)
plt.colorbar(c3, ax=axes[3],shrink=0.5)
plt.colorbar(c4, ax=axes[4],shrink=0.5)

plt.tight_layout() # Adjust subplot parameters for a tight layout
plt.show()

# %%
#### High-Resolution Query ####

# Query the trained SIREN on a denser coordinate grid than the training
# resolution.  `high_res_sidelength` can be any integer because a
# fresh mgrid will be built rather than resampling the original pixel array.

high_res_sidelength = sidelength * 5   # define the new sidelength we want to query at

# Build the high-res coordinate grid (still in [-1, 1] x [-1, 1])
high_res_coords = get_mgrid(high_res_sidelength, dim=2)   # shape: (high_res_sidelength**2, 2)

# Allocate output tensor on CPU
high_res_output = torch.empty(high_res_sidelength ** 2, 1)

high_res_batch_size = 65536 #256^2
high_res_num_batches = (high_res_sidelength ** 2 + high_res_batch_size - 1) // high_res_batch_size

img_siren.eval()
with torch.no_grad():
    chunks = high_res_coords.split(high_res_batch_size)
    results = []
    for i, chunk in enumerate(chunks):
        batch_out, _ = img_siren(chunk.cuda().float())
        results.append(batch_out.cpu())
        if i % max(1, len(chunks) // 5) == 0:
            print(f"  batch {i+1}/{len(chunks)}")
    high_res_output = torch.cat(results, dim=0)

print(f"High-resolution query: {high_res_sidelength}×{high_res_sidelength} pixels")
high_res_image = high_res_output.view(high_res_sidelength, high_res_sidelength).numpy()
# Out:
#   batch 1/1600
#   batch 321/1600
#   batch 641/1600
#   batch 961/1600
#   batch 1281/1600
# High-resolution query: 10240×10240 pixels

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 14))


# Training-resolution reconstruction
im0 = axes[0].imshow(
    full_model_output.cpu().view(sidelength, sidelength).numpy(),
    cmap='magma'
)
axes[0].set_title(f"Trained resolution ({sidelength}×{sidelength})")
axes[0].axis('off')
plt.colorbar(im0, ax=axes[0], shrink=0.7, fraction=0.046, pad=0.04)

# High-resolution query
im1 = axes[1].imshow(high_res_image, cmap='magma',)
axes[1].set_title(f"High-res query ({high_res_sidelength}×{high_res_sidelength})")
axes[1].axis('off')
plt.colorbar(im1, ax=axes[1], shrink=0.7, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()

# %%
from skimage.transform import resize
from skimage.metrics import structural_similarity as ssim, peak_signal_noise_ratio as psnr

# Ground truth
original = milkyway.get_pixels().view(sidelength, sidelength).numpy()

# Trained output (currently at some resolution as ground truth)
trained = full_model_output.cpu().view(sidelength, sidelength).numpy()

# Downsample the high-res query back to ground truth resolution
high_res_downsampled = resize(high_res_image, (sidelength, sidelength), anti_aliasing=True)

data_range = original.max() - original.min()

#### Some statistics ####

# MAE — Mean Absolute Error
#     For every pixel, take the absolute difference between the two images and average them all.
#     A value of 0 means the images are identical.

# PSNR — Peak Signal-to-Noise Ratio
#     Essentially a logarithmic version of the mean squared error, normalised
#     by the maximum possible pixel value. Higher is better. Sensitive to outliers
#     Note: small differences at high values bias more than small differences at the low end (need to
#     be aware of this).
#     Note: these are also calculated on a pixlel to pixel basis


# SSIM — Structural Similarity Index
#     Rather than comparing pixels individually, it compares local patches across
#     the image in terms of three things: luminance (are the brightness levels similar),
#     contrast (are the local variations similar), and structure (are the spatial patterns similar).
#     The result is a value between -1 and 1, where 1 means identical.


## Trained output vs. ground truth ##
print("Trained output vs. ground truth:")
print(f"  MAE:   {np.abs(original - trained).mean()}")
print(f"  PSNR:  {psnr(original, trained, data_range=data_range)} dB")
print(f"  SSIM:  {ssim(original, trained, data_range=data_range)}")



print()

## High-res query (downsampled) vs. ground truth ##
print("High-res query vs. ground truth:")
print(f"  MAE:   {np.abs(original - high_res_downsampled).mean()}")
print(f"  PSNR:  {psnr(original, high_res_downsampled, data_range=data_range)} dB")
print(f"  SSIM:  {ssim(original, high_res_downsampled, data_range=data_range)}")



print()

## Trained vs. high-res  ##

# High numbers here would mean the high res is a faithful upsampling of what the network learned
# rather than drifting or introducing new artefacts

print("Trained output vs. high-res query:")
print(f"  MAE:   {np.abs(trained - high_res_downsampled).mean()}")
print(f"  PSNR:  {psnr(trained, high_res_downsampled, data_range=trained.max()-trained.min())} dB")
print(f"  SSIM:  {ssim(trained, high_res_downsampled, data_range=trained.max()-trained.min())}")
# Out:
# Trained output vs. ground truth:
#   MAE:   0.00996595062315464
#   PSNR:  42.38866869690517 dB
#   SSIM:  0.958272804581969
#
# High-res query vs. ground truth:
#   MAE:   0.009992814622819424
#   PSNR:  42.362458299334655 dB
#   SSIM:  0.9581229418504509
#
# Trained output vs. high-res query:
#   MAE:   0.0004379830788820982
#   PSNR:  62.30954589130957 dB
#   SSIM:  0.9996055976141432
